# %% [markdown]
# <a href="https://colab.research.google.com/github/sum78435-lang/pythontibame/blob/main/tablelogscrap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.request as req
import bs4 as bs

def get_page(page_num):
  url = "https://tabelog.com/tw/kagoshima/rstLst/sushi/?SrtT=rt"
  resp = req.urlopen(url)
  content = resp.read()
  html = bs.BeautifulSoup(content)
  # html.find("a",{"class":"list-rst__rst-name-target"})
  rst = html.find_all("div",{"class":"list-rst__body"})

  result=[]
  for r in rst:
    name = r.find("a",{"class":"list-rst__rst-name-target"})
    area_genre = r.find("div",{"class":"list-rst__area-genre"})
    rating = r.find("span",{"class":"c-rating__val"})
    prices = r.find_all("span",{"class":"c-rating-v3__val"})
    dinner_price = prices[0]
    lunch_price = prices[1]
    holiday = r.find("span",{"class":"list-rst__holiday-text"})
    imgs = r.find_all("img",{"class":"js-thumbnail-img"})

    name_href = name["href"]
    name_text = name.get_text()
    area_genre_text = area_genre.get_text().strip()
    rating_text = rating.get_text().strip()
    dinner_price_text = dinner_price.get_text().strip()
    lunch_price_text = lunch_price.get_text().strip()
    holiday_text = holiday.get_text().strip()

    imgs_src = []
    for img in imgs:
      imgs_src.append(img["src"])

    #imgs_src = [img["src"] for img in imgs]
    data = {
    "rating":rating_text,
    "name":name_text,
    "link":name_href,
    "imgs":imgs_src,
    "area_genre":area_genre_text,
    "price_dinner":dinner_price_text,
    "price_lunch":lunch_price_text,
    "holiday":holiday_text,
    }
    result.append(data)
# Out:
# 4.38
# 鮨匠 Nomura
# https://tabelog.com/tw/kagoshima/A4601/A460101/46000087/
# 天文館通車站 456m / 壽司
# JPY 40,000 - JPY 49,999
# -
# -
# ------------------------------
# 4.23
# 名山 Kimiya
# https://tabelog.com/tw/kagoshima/A4601/A460101/46010277/
# 市政厅車站 100m / 壽司, 日本料理, 海鮮
# JPY 30,000 - JPY 39,999
# JPY 20,000 - JPY 29,999
# -
# ------------------------------
# 3.77
# 壽司馨
# https://tabelog.com/tw/kagoshima/A4601/A460101/46009644/
# 高见马场車站 135m / 壽司, 日本料理, 海鮮
# JPY 10,000 - JPY 14,999
# JPY 3,000 - JPY 3,999
# 星期一
# ------------------------------
# 3.75
# 壽司處 Kimiya
# https://tabelog.com/tw/kagoshima/A4601/A460101/46016654/
# 脇田車站 27m / 壽司
# JPY 5,000 - JPY 5,999
# JPY 4,000 - JPY 4,999
# 星期三, 星期四
# ------------------------------
# 3.74
# 紫光
# https://tabelog.com/tw/kagoshima/A4601/A460101/46000088/
# 天文館通車站 152m / 壽司
# JPY 15,000 - JPY 19,999
# JPY 8,000 - JPY 9,999
# 星期一, 星期二
# ------------------------------
# 3.72
# 市場食堂 城南店
# https://tabelog.com/tw/kagoshima/A4601/A460101/46000812/
# IZURO通車站 1089m / 食堂, 壽司, 海鮮
# -
# JPY 1,000 - JPY 1,999
# 星期日, 節假日
# ------------------------------
# 3.63
# 迴轉壽司 Mekkemonn Dolphin Port店
# https://tabelog.com/tw/kagoshima/A4601/A460101/46014192/
# IZURO通車站 454m / 回轉壽司
# JPY 2,000 - JPY 2,999
# JPY 2,000 - JPY 2,999
# -
# ------------------------------
# 3.62
# 船頭料理 魚莊
# https://tabelog.com/tw/kagoshima/A4601/A460101/46000234/
# 都通車站 87m / 海鮮, 居酒屋 (酒館), 壽司
# JPY 6,000 - JPY 7,999
# -
# 星期日
# ------------------------------
# 3.61
# 壽司 碧海
# https://tabelog.com/tw/kagoshima/A4605/A460502/46014081/
# 壽司
# JPY 8,000 - JPY 9,999
# -
# -
# ------------------------------
# 3.56
# 太郎壽司
# https://tabelog.com/tw/kagoshima/A4602/A460203/46002327/
# 阿久根車站 310m / 壽司, 海鮮, 鰻魚
# JPY 4,000 - JPY 4,999
# JPY 2,000 - JPY 2,999
# -
# ------------------------------
# 3.54
# Sushi Ko Katsuo
# https://tabelog.com/tw/kagoshima/A4601/A460101/46014785/
# 鹿兒島中央站前車站 110m / 海鮮, 居酒屋 (酒館), 壽司
# JPY 2,000 - JPY 2,999
# - JPY 999
# -
# ------------------------------
# 3.51
# 鮨 Pin
# https://tabelog.com/tw/kagoshima/A4601/A460101/46014508/
# 天文館通車站 138m / 壽司
# JPY 20,000 - JPY 29,999
# -
# -
# ------------------------------
# 3.50
# 壽司屋之山八
# https://tabelog.com/tw/kagoshima/A4603/A460301/46001296/
# 國分車站 676m / 壽司, 海鮮
# JPY 8,000 - JPY 9,999
# -
# -
# ------------------------------
# 3.46
# 黑醋之鄉 桷志田
# https://tabelog.com/tw/kagoshima/A4603/A460301/46000814/
# 創作料理, 壽司, 西式料理
# -
# JPY 1,000 - JPY 1,999
# -
# ------------------------------
# 3.39
# 廻轉壽司 Mekkemonn 鹿兒島中央站店
# https://tabelog.com/tw/kagoshima/A4601/A460101/46005807/
# 鹿兒島中央車站 66m / 回轉壽司
# JPY 2,000 - JPY 2,999
# JPY 1,000 - JPY 1,999
# -
# ------------------------------
# 3.39
# 市場食堂 天文館店
# https://tabelog.com/tw/kagoshima/A4601/A460101/46000059/
# 天文館通車站 271m / 壽司, 郷土料理
# JPY 4,000 - JPY 4,999
# -
# 星期日
# ------------------------------
# 3.37
# 健美和樂 Hanan ka
# https://tabelog.com/tw/kagoshima/A4601/A460101/46001017/
# 谷山車站 846m / 郷土料理, 日本料理, 壽司
# JPY 2,000 - JPY 2,999
# JPY 1,000 - JPY 1,999
# -
# ------------------------------
# 3.36
# 迴轉壽司七八
# https://tabelog.com/tw/kagoshima/A4603/A460303/46007566/
# 重富車站 313m / 回轉壽司
# JPY 2,000 - JPY 2,999
# JPY 1,000 - JPY 1,999
# -
# ------------------------------
# 3.35
# 海鮮鮪魚家
# https://tabelog.com/tw/kagoshima/A4602/A460202/46010257/
# 串木野車站 722m / 壽司, 海鮮, 海鮮蓋飯
# JPY 1,000 - JPY 1,999
# JPY 1,000 - JPY 1,999
# -
# ------------------------------
# 3.34
# 迴轉壽司 Mekkemonn 國分店
# https://tabelog.com/tw/kagoshima/A4603/A460301/46009724/
# 國分車站 506m / 回轉壽司
# JPY 3,000 - JPY 3,999
# JPY 2,000 - JPY 2,999
# -
# ------------------------------

# %%
total = []
for i in range(5):
  page = i + 1
  partial = get_page(page)
  total = total + partial
total

# %%
import urllib.request as req
url = "https://i.imgur.com/QMTqVne.jpeg"
h = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/150.0.0.0 Safari/537.36"}
r = req.Request(url,headers=h)
resp = req.urlopen(r)
content = resp.read()
f = open("ichika.png","wb")
f.write(content)
f.close()

# %%
import urllib.request as req
url = "https://images.ctfassets.net/hnoi7ctzfs57/3fipDWXSuTI3FFCGAVaf6E/699ebcb78f32aa42e4f30618ef192971/tk8_King.png"
r = req.urlopen(url)
resp = r.read()
f = open("tekken8.png","wb")
f.write(resp)
f.close()

# %%
import pandas as pd
demo = pd.DataFrame([[1,2],[3,4],[5,6]],columns=["a","b"])
demo["a"].apply(float)

def func(n):
  import random
  n = n + random.uniform(-1,1)
  return n
demo["a"].apply(func)
# Out:
# 0    1.731868
# 1    3.694842
# 2    4.627621
# Name: a, dtype: float64
