# %% [markdown]
# <a href="https://colab.research.google.com/github/sum78435-lang/pythontibame/blob/main/webscrap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import urllib.request as req
import os
import json
import pandas as pd

serials = ["35241","35242","35243"]
dn = "baha/芙莉蓮"
def get_danmu(sn,dn,chapter):
  if not os.path.exists(dn):
    os.makedirs(dn)
  url = f"https://api.gamer.com.tw/anime/v1/danmu.php?videoSn={sn}&geo=TW%2CHK"
  print("下載",url)

  f = req.urlopen(url)
  content = f.read()
  content = json.loads(content)
  danmus = content["data"]["danmu"]

  df = pd.DataFrame(danmus)
  df["ch"] = chapter
  df.to_csv(f"{dn}/{sn}.csv",encoding="utf-8")
  return df




# for d in danmus:
#   print(d["userid"],d["text"])

# %%
f = open("test.csv","w",encoding="utf-8")
f.write("姓名,身高\n")
f.write("Andy,174\n")
f.write('"Bob,Mr.Chou",180')
f.close()

# %%
import os
import urllib.request as req
import bs4 as bs
# url ="https://ani.gamer.com.tw/animeVideo.php?sn=35241"
# url = "https://github.com/Elwing-Chou/tibame20260427/raw/refs/heads/main/%E8%8A%99%E8%8E%89%E8%93%AE.html"
url = "https://github.com/sum78435-lang/pythontibame/raw/refs/heads/main/%E8%8A%99%E8%8E%89%E8%93%AE.html"

h = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/150.0.0.0 Safari/537.36"
}

r = req.Request(url,headers=h)
resp = req.urlopen(r)
content = resp.read()
html = bs.BeautifulSoup(content)
for a in html.find_all("a"):
  a_href = a["href"]
  a_text = a.get_text()
  if a_href.startswith("?sn"):
    print(a_text,a_href)
# Out:
# 1 ?sn=35241
# 2 ?sn=35242
# 3 ?sn=35243
# 4 ?sn=35244
# 5 ?sn=35445
# 6 ?sn=35446
# 7 ?sn=35447
# 8 ?sn=35660
# 9 ?sn=35781
# 10 ?sn=35845
# 11 ?sn=36046
# 12 ?sn=36128
# 13 ?sn=36196
# 14 ?sn=36260
# 15 ?sn=36371
# 16 ?sn=36553
# 17 ?sn=36554
# 18 ?sn=36861
# 19 ?sn=36862
# 20 ?sn=36991
# 21 ?sn=37034
# 22 ?sn=37100
# 23 ?sn=37237
# 24 ?sn=37362
# 25 ?sn=37407
# 26 ?sn=37408
# 27 ?sn=37628
# 28 ?sn=37668
# 1 ?sn=39208
# 2 ?sn=39209
# 3 ?sn=39210
# 4 ?sn=39211
# 5 ?sn=39212
# 6 ?sn=39213
# 7 ?sn=39214
# 8 ?sn=39215
# 9 ?sn=39216
# 10 ?sn=39217
# 11 ?sn=39218
# 12 ?sn=39219
# 13 ?sn=39220
# 14 ?sn=39221
# 15 ?sn=39222
# 16 ?sn=39223
# 17 ?sn=39224
# 18 ?sn=39225
# 19 ?sn=39226
# 20 ?sn=39227
# 21 ?sn=39228
# 22 ?sn=39229
# 23 ?sn=39230
# 24 ?sn=39231
# 25 ?sn=39232
# 26 ?sn=39233
# 27 ?sn=39234
# 28 ?sn=39235

# %%
df = get_danmu("35421","baha/芙莉蓮")
df["text"]
cols = ["text","userid"]
df[cols]
df["new"] = 20
df
# Out:
# 下載 https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=35421&geo=TW%2CHK
#                   text    color  size  position   time        sn  \
# 0           簽簽ukyo四刷！！  #FFFFFF     1         0      0  46978783
# 1    2024最後一天看到這集，真是感動  #FFFFFF     1         0      1  43290413
# 2                 簽！！！  #A7FE39     2         0      6  35944748
# 3          2023/10/20簽  #FFFFFF     1         0      6  35948122
# 4                   簽🥖  #FF9496     1         0      8  49266942
# ..                 ...      ...   ...       ...    ...       ...
# 928               太神辣！  #FFFFFF     1         0  14337  35934309
# 929          自己google啦  #FF9496     2         2  14340  36963108
# 930   該不會是兩人份3D拼圖混在一起了  #FFFFFF     1         0  14345  35988966
# 931    無水硫酸銅(白色) 碰水>藍色  #FFFFFF     1         0  14345  36229553
# 932                 安安  #FFFFFF     1         0  14400  35933142
#
#            userid  new
# 0      mishia0404   20
# 1        ss717678   20
# 2       Cat971110   20
# 3     sunny990803   20
# 4    alice1025102   20
# ..            ...  ...
# 928       b730091   20
# 929     z55423674   20
# 930        areong   20
# 931  andyas123456   20
# 932      petet520   20
#
# [933 rows x 8 columns]
